# %% [markdown]
# ## Profitable App Profiles for the App Store and Google Play Markets
#
# For this project, we'll pretend we're working as data analysts for a company that builds Android and iOS mobile apps. We make our apps available on Google Play and the App Store.
#
# We only build apps that are free to download and install, and our main source of revenue consists of in-app ads. This means our revenue for any given app is mostly influenced by the number of users who use our app. Our goal for this project is to analyze data to help our developers understand what kinds of apps are likely to attract more users.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
apple = pd.read_csv("AppleStore.csv")
google = pd.read_csv("googleplaystore.csv")

# %% [markdown]
# ## Sneak Peak at the Data
#
# We'll be workng with two data sets in this project.
#
# - A data set containing data about approximately ten thousand Android apps from Google Play — the data was collected in August 2018
#     - https://www.kaggle.com/lava18/google-play-store-apps
# - A data set containing data about approximately seven thousand iOS apps from the App Store — the data was collected in July 2017
#     - https://www.kaggle.com/ramamet4/app-store-apple-data-set-10k-apps

# %%
apple.head(2)
# Out:
#           id track_name  size_bytes currency  price  rating_count_tot  \
# 0  284882215   Facebook   389879808      USD    0.0           2974676
# 1  389801252  Instagram   113954816      USD    0.0           2161558
#
#    rating_count_ver  user_rating  user_rating_ver    ver cont_rating  \
# 0               212          3.5              3.5   95.0          4+
# 1              1289          4.5              4.0  10.23         12+
#
#          prime_genre  sup_devices.num  ipadSc_urls.num  lang.num  vpp_lic
# 0  Social Networking               37                1        29        1
# 1      Photo & Video               37                0        29        1

# %%
apple.describe()
# Out:
#                  id    size_bytes        price  rating_count_tot  \
# count  7.197000e+03  7.197000e+03  7197.000000      7.197000e+03
# mean   8.631310e+08  1.991345e+08     1.726218      1.289291e+04
# std    2.712368e+08  3.592069e+08     5.833006      7.573941e+04
# min    2.816565e+08  5.898240e+05     0.000000      0.000000e+00
# 25%    6.000937e+08  4.692275e+07     0.000000      2.800000e+01
# 50%    9.781482e+08  9.715302e+07     0.000000      3.000000e+02
# 75%    1.082310e+09  1.819249e+08     1.990000      2.793000e+03
# max    1.188376e+09  4.025970e+09   299.990000      2.974676e+06
#
#        rating_count_ver  user_rating  user_rating_ver  sup_devices.num  \
# count       7197.000000  7197.000000      7197.000000      7197.000000
# mean         460.373906     3.526956         3.253578        37.361817
# std         3920.455183     1.517948         1.809363         3.737715
# min            0.000000     0.000000         0.000000         9.000000
# 25%            1.000000     3.500000         2.500000        37.000000
# 50%           23.000000     4.000000         4.000000        37.000000
# 75%          140.000000     4.500000         4.500000        38.000000
# max       177050.000000     5.000000         5.000000        47.000000
#
#        ipadSc_urls.num     lang.num      vpp_lic
# count      7197.000000  7197.000000  7197.000000
# mean          3.707100     5.434903     0.993053
# std           1.986005     7.919593     0.083066
# min           0.000000     0.000000     0.000000
# 25%           3.000000     1.000000     1.000000
# 50%           5.000000     1.000000     1.000000
# 75%           5.000000     8.000000     1.000000
# max           5.000000    75.000000     1.000000

# %%
google.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews Size  Installs  Type Price Content Rating  \
# 0     159  19M   10,000+  Free     0       Everyone
# 1     967  14M  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
google.describe(include='all')
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
#          Type  Price Content Rating Genres    Last Updated  \
# count   10840  10841          10840  10841           10841
# unique      3     93              6    120            1378
# top      Free      0       Everyone  Tools  August 3, 2018
# freq    10039  10040           8714    842             326
# mean      NaN    NaN            NaN    NaN             NaN
# std       NaN    NaN            NaN    NaN             NaN
# min       NaN    NaN            NaN    NaN             NaN
# 25%       NaN    NaN            NaN    NaN             NaN
# 50%       NaN    NaN            NaN    NaN             NaN
# 75%       NaN    NaN            NaN    NaN             NaN
# max       NaN    NaN            NaN    NaN             NaN
#
#                Current Ver Android Ver
# count                10833       10838
# unique                2832          33
# top     Varies with device  4.1 and up
# freq                  1459        2451
# mean                   NaN         NaN
# std                    NaN         NaN
# min                    NaN         NaN
# 25%                    NaN         NaN
# 50%                    NaN         NaN
# 75%                    NaN         NaN
# max                    NaN         NaN

# %% [markdown]
# ## Data Cleaning
# ### Part 1: Modifying incorret data entry
# The Google Play data set has a dedicated discussion section, and we can see that one of the discussions outlines an error for row 10472. Let's print this row and compare it against the header and another row that is correct.

# %%
google.loc[10471:10473,:]
# Out:
#                                            App         Category  Rating  \
# 10471                         Xposed Wi-Fi-Pwd  PERSONALIZATION     3.5
# 10472  Life Made WI-Fi Touchscreen Photo Frame              1.9    19.0
# 10473                  osmino Wi-Fi: free WiFi            TOOLS     4.2
#
#       Reviews    Size     Installs  Type     Price Content Rating  \
# 10471    1042    404k     100,000+  Free         0       Everyone
# 10472    3.0M  1,000+         Free     0  Everyone            NaN
# 10473  134203    4.1M  10,000,000+  Free         0       Everyone
#
#                   Genres    Last Updated Current Ver   Android Ver
# 10471    Personalization  August 5, 2014       3.0.0  4.0.3 and up
# 10472  February 11, 2018          1.0.19  4.0 and up           NaN
# 10473              Tools  August 7, 2018     6.06.14    4.4 and up

# %% [markdown]
# It appears that row 10472 has *Category* missing and a column shift for next couple values. Instead of deleting this row, we'll modify it to make its column values consistent with the header row.

# %%
google.iloc[10472,1:] = google.iloc[10472,1:].shift(1)

# %% [markdown]
# Now row 10472 looks correct with *Category* missing.

# %%
google.loc[10472,:]
# Out:
# App               Life Made WI-Fi Touchscreen Photo Frame
# Category                                              NaN
# Rating                                                1.9
# Reviews                                                19
# Size                                                 3.0M
# Installs                                           1,000+
# Type                                                 Free
# Price                                                   0
# Content Rating                                   Everyone
# Genres                                                NaN
# Last Updated                            February 11, 2018
# Current Ver                                        1.0.19
# Android Ver                                    4.0 and up
# Name: 10472, dtype: object

# %% [markdown]
# ### Part 2 : Removing duplicate entries
#
# We notice that there are some duplicate entries for the same App in the GooglePlay dataset. For example:

# %%
google[google["App"]== "Instagram"]
# Out:
#             App Category Rating   Reviews                Size        Installs  \
# 2545  Instagram   SOCIAL    4.5  66577313  Varies with device  1,000,000,000+
# 2604  Instagram   SOCIAL    4.5  66577446  Varies with device  1,000,000,000+
# 2611  Instagram   SOCIAL    4.5  66577313  Varies with device  1,000,000,000+
# 3909  Instagram   SOCIAL    4.5  66509917  Varies with device  1,000,000,000+
#
#       Type Price Content Rating  Genres   Last Updated         Current Ver  \
# 2545  Free     0           Teen  Social  July 31, 2018  Varies with device
# 2604  Free     0           Teen  Social  July 31, 2018  Varies with device
# 2611  Free     0           Teen  Social  July 31, 2018  Varies with device
# 3909  Free     0           Teen  Social  July 31, 2018  Varies with device
#
#              Android Ver
# 2545  Varies with device
# 2604  Varies with device
# 2611  Varies with device
# 3909  Varies with device

# %% [markdown]
# Let's count the number of duplicate entries to confirm.

# %%
app_entry = {}
for name in google.App:
    if name in app_entry:
        app_entry[name] += 1
    else:
        app_entry[name] = 1

# %%
duplicate = dict((k, v) for k, v in app_entry.items() if v > 1)
single =  dict((k, v) for k, v in app_entry.items() if v == 1)
print(len(duplicate))
print(len(single))
# Out:
# 798
# 8862

# %% [markdown]
# We don't want to count certain apps more than once when we analyze data, so we need to remove the duplicate entries. Examining the rows we printed out for Instagram, we see that the main difference between the multple entries lies in the fourth position of each row, which identifies the number of reviews. Because the higher number of reviews correspond to the more recent entry, we will only keep the entry with highest review counts in the case of duplicate entries.

# %%
google["Reviews"] = pd.to_numeric(google["Reviews"], errors="coerce")
google_sorted = google.sort_values(by=["App", "Reviews"])
google = google_sorted.drop_duplicates(subset="App", keep="last")
# # Create a dictionary to store the highest number of reviews
# app_review = {}
# for index, row in google.iterrows():
#     name = row["App"]
#     review = row["Reviews"]
#     if name in app_review:
#         if review > app_review[name]:
#             app_review[name] = review
#     else:
#         app_review[name] = review
# print(len(app_review))

# %% [markdown]
# ### Part 3: Removing non-English Apps

# %% [markdown]
# The numbers corresponding to the characters we commonly use in an English text are all in the range 0 to 127, according to the ASCII (American Standard Code for Information Interchange) system. Based on this number range, we can build a function that detects whether a character belongs to the set of common English characters or not. If the number is equal to or less than 127, then the character belongs to the set of common English characters, otherwise it doesn't.

# %%
def check_eng(string):
    num_special = 0
    for char in string:
        if ord(char) > 127:
            num_special += 1
    return num_special <= 3

# %% [markdown]
# Let's test if our check_eng function works as expected.

# %%
print(check_eng("爱奇艺PPS -《欢乐颂2》电视剧热播"))
print(check_eng("Instachat 😜"))
print(check_eng('Docs To Go™ Free Office Suite'))
# Out:
# False
# True
# True

# %% [markdown]
# Now we'll use our check_eng function to filter out non-English apps from both Google datasets and Apple datasets.

# %%
google["IfEnglish"] = google["App"].apply(check_eng)

# %% [markdown]
# Let's manually exmaine the rows we removed just to ensure that our check_eng function did the right thing.

# %%
google[google["IfEnglish"]==0]
# Out:
#                                                      App             Category  \
# 5266                                       AJ렌터카 법인 카셰어링  MAPS_AND_NAVIGATION
# 5346                      Al Quran Free - القرآن (Islam)  BOOKS_AND_REFERENCE
# 5841                           Ay Yıldız Duvar Kağıtları      PERSONALIZATION
# 9971                             AÖF Ev İdaresi 1. Sınıf               FAMILY
# 6417                                   BL 女性向け恋愛ゲーム◆ごくメン               FAMILY
# 6406                                 BL 女性向け恋愛ゲーム◆俺プリクロス               FAMILY
# 6629                                  BQ-መጽሐፍ ቅዱሳዊ ጥያቄዎች                 GAME
# 6729                        BS Calendar / Patro / पात्रो         PRODUCTIVITY
# 7396                       Bonjour 2017 Abidjan CI ❤❤❤❤❤               FAMILY
# 7463                                            CK 初一 十五            LIFESTYLE
# 6165                                         Cъновник BG  BOOKS_AND_REFERENCE
# 8394                   DG ग्राम / Digital Gram Panchayat   NEWS_AND_MAGAZINES
# 8567                                            DM הפקות          PHOTOGRAPHY
# 8994                             DW فارسی By dw-arab.com   NEWS_AND_MAGAZINES
# 9248                                           ECナビ×シュフー            LIFESTYLE
# 9317                      EG SIM CARD (EGSIMCARD, 이지심카드)             BUSINESS
# 10098                     Ey Sey Storytime រឿងនិទានតាឥសី               FAMILY
# 9777                           FAHREDDİN er-RÂZİ TEFSİRİ  BOOKS_AND_REFERENCE
# 10763                                FP Разбитый дисплей               FAMILY
# 710                               Flame - درب عقلك يوميا            EDUCATION
# 4324   L.POINT - 엘포인트 [ 포인트, 멤버십, 적립, 사용, 모바일 카드, 쿠폰,...            LIFESTYLE
# 7290                      Offline Jízdní řády CG Transit  MAPS_AND_NAVIGATION
# 4550                   RMEduS - 음성인식을 활용한 R 프로그래밍 실습 시스템               FAMILY
# 6415                       SecondSecret ‐「恋を読む」BLノベルゲーム‐                 GAME
# 6805                                     Vip视频免费看-BT磁力搜索                TOOLS
# 3750                                         РИА Новости   NEWS_AND_MAGAZINES
# 9308             أحداث وحقائق | خبر عاجل في اخبار العالم   NEWS_AND_MAGAZINES
# 7751                                 الفاتحون Conquerors               FAMILY
# 4193                                           صور حرف H       ART_AND_DESIGN
# 9117                                   لعبة تقدر تربح DZ               FAMILY
# 6006                        বাংলা টিভি প্রো BD Bangla TV               FAMILY
# 9200                                           বাংলাflix               FAMILY
# 1592              သိင်္ Astrology - Min Thein Kha BayDin            LIFESTYLE
# 6418                                       あなカレ【BL】無料ゲーム               FAMILY
# 9466                     パーリーゲイツ公式通販｜EJ STYLE（イージェイスタイル）             SHOPPING
# 5513                                         中国語 AQリスニング               FAMILY
# 10109                                            哈哈姆特不EY        COMMUNICATION
# 5698                                              日本AV历史  BOOKS_AND_REFERENCE
# 9222                                  英漢字典 EC Dictionary               FAMILY
# 6420                                         감성학원 BL 첫사랑               COMICS
# 6334                             뽕티비 - 개인방송, 인터넷방송, BJ방송        VIDEO_PLAYERS
#
#       Rating   Reviews                Size    Installs  Type Price  \
# 5266     NaN       0.0                 27M         10+  Free     0
# 5346     4.7    1777.0                 23M     50,000+  Free     0
# 5841     NaN       3.0                6.5M        100+  Free     0
# 9971     NaN       2.0                 11M      1,000+  Free     0
# 6417     4.2    1901.0                8.2M    100,000+  Free     0
# 6406     4.2    3379.0                 62M    100,000+  Free     0
# 6629     4.7     191.0                7.2M      5,000+  Free     0
# 6729     4.2     218.0  Varies with device     50,000+  Free     0
# 7396     NaN     235.0                3.3M     10,000+  Free     0
# 7463       4     294.0                153k     10,000+  Free     0
# 6165     NaN      13.0                4.1M      1,000+  Free     0
# 8394     4.5      53.0                5.9M     10,000+  Free     0
# 8567     NaN       2.0                 10M        100+  Free     0
# 8994     4.7      11.0                4.4M      1,000+  Free     0
# 9248       4     576.0                7.4M     50,000+  Free     0
# 9317     2.9     322.0                1.5M     50,000+  Free     0
# 10098    4.7    1327.0                 44M     10,000+  Free     0
# 9777     NaN       9.0                 20M      1,000+  Free     0
# 10763    4.5     922.0                552k     50,000+  Free     0
# 710      4.6   56065.0                 37M  1,000,000+  Free     0
# 4324       4   45224.0                 49M  5,000,000+  Free     0
# 7290     4.6    7314.0                7.0M    100,000+  Free     0
# 4550     NaN       4.0                 64M          1+  Free     0
# 6415     4.4    1563.0                 40M     50,000+  Free     0
# 6805     NaN      20.0                7.9M      1,000+  Free     0
# 3750     4.5   44274.0                8.0M  1,000,000+  Free     0
# 9308     4.8     311.0                 14M      5,000+  Free     0
# 7751     4.5  108130.0                 40M  5,000,000+  Free     0
# 4193     4.4      13.0                4.5M      1,000+  Free     0
# 9117     4.2     238.0                6.8M     10,000+  Free     0
# 6006     4.3     193.0                 14M     10,000+  Free     0
# 9200     4.2    1111.0                7.3M    100,000+  Free     0
# 1592     4.7    2225.0                 15M    100,000+  Free     0
# 6418     4.7    6073.0                8.5M    100,000+  Free     0
# 9466     NaN       1.0                9.3M        100+  Free     0
# 5513     NaN      21.0                 17M      5,000+  Free     0
# 10109    NaN     239.0                 18M     10,000+  Free     0
# 5698     4.1     215.0                 30M     10,000+  Free     0
# 9222     4.3   55408.0  Varies with device  1,000,000+  Free     0
# 6420     4.4     190.0                 34M     10,000+  Free     0
# 6334     NaN     414.0                 59M    100,000+  Free     0
#
#       Content Rating                   Genres        Last Updated  \
# 5266        Everyone        Maps & Navigation       July 30, 2018
# 5346        Everyone        Books & Reference   February 15, 2015
# 5841        Everyone          Personalization   December 10, 2017
# 9971        Everyone                Education       July 15, 2018
# 6417      Mature 17+               Simulation        July 7, 2016
# 6406      Mature 17+               Simulation      March 23, 2017
# 6629        Everyone                   Trivia       July 31, 2018
# 6729        Everyone             Productivity       July 15, 2018
# 7396        Everyone            Entertainment   February 16, 2017
# 7463        Everyone                Lifestyle        July 3, 2013
# 6165        Everyone        Books & Reference    January 21, 2017
# 8394            Teen         News & Magazines       June 19, 2018
# 8567        Everyone              Photography    October 14, 2017
# 8994        Everyone         News & Magazines      March 26, 2017
# 9248        Everyone                Lifestyle        June 7, 2018
# 9317        Everyone                 Business      March 28, 2017
# 10098       Everyone      Education;Education        May 18, 2017
# 9777        Everyone        Books & Reference      March 19, 2018
# 10763       Everyone            Entertainment  September 20, 2014
# 710         Everyone                Education       July 26, 2018
# 4324        Everyone                Lifestyle      August 1, 2018
# 7290        Everyone        Maps & Navigation   September 7, 2017
# 4550        Everyone                Education       July 17, 2018
# 6415            Teen                Adventure       June 29, 2017
# 6805        Everyone                    Tools        June 8, 2018
# 3750        Everyone         News & Magazines      August 6, 2018
# 9308    Everyone 10+         News & Magazines       July 15, 2018
# 7751            Teen                 Strategy      August 3, 2018
# 4193        Everyone             Art & Design      March 27, 2018
# 9117        Everyone                Education   November 18, 2016
# 6006        Everyone            Entertainment      April 29, 2017
# 9200        Everyone            Entertainment        June 5, 2018
# 1592        Everyone                Lifestyle       July 26, 2018
# 6418      Mature 17+               Simulation   February 25, 2018
# 9466        Everyone                 Shopping   November 16, 2017
# 5513        Everyone                Education       June 22, 2016
# 10109       Everyone            Communication       July 31, 2018
# 5698            Teen        Books & Reference       March 6, 2018
# 9222        Everyone                Education     January 8, 2018
# 6420        Everyone                   Comics   November 17, 2017
# 6334      Mature 17+  Video Players & Editors       July 18, 2018
#
#               Current Ver         Android Ver  IfEnglish
# 5266              1.0.0.0          4.3 and up      False
# 5346                  1.1          2.2 and up      False
# 5841                1.0.0          4.3 and up      False
# 9971                  3.0          4.1 and up      False
# 6417                1.3.0        2.3.3 and up      False
# 6406                1.6.3        2.3.3 and up      False
# 6629                4.1.2          4.1 and up      False
# 6729   Varies with device  Varies with device      False
# 7396              1.0.2.0          2.0 and up      False
# 7463               1.0.12          2.1 and up      False
# 6165                  250          4.0 and up      False
# 8394                  1.7          4.0 and up      False
# 8567                 30.0          3.2 and up      False
# 8994                1.0.0          4.1 and up      False
# 9248                1.0.2          4.0 and up      False
# 9317                 2.13          2.2 and up      False
# 10098               1.2.2        4.0.3 and up      False
# 9777                  1.1        4.0.3 and up      False
# 10763                 1.1          1.6 and up      False
# 710                   3.3          4.1 and up      False
# 4324                6.5.1          4.1 and up      False
# 7290                3.1.4          4.0 and up      False
# 4550                1.0.1          4.4 and up      False
# 6415                1.3.6          4.0 and up      False
# 6805                  1.2          4.0 and up      False
# 3750                4.0.6          4.4 and up      False
# 9308              2.9.19a          4.2 and up      False
# 7751                1.8.0          4.0 and up      False
# 4193                  2.0        4.0.3 and up      False
# 9117              6.0.0.0          4.1 and up      False
# 6006                  1.3          4.0 and up      False
# 9200                3.6.1          4.1 and up      False
# 1592                4.2.1        4.0.3 and up      False
# 6418                4.2.2          2.3 and up      False
# 9466                  3.0        4.0.3 and up      False
# 5513                2.4.0          4.0 and up      False
# 10109               1.3.4          4.4 and up      False
# 5698                  1.2          4.0 and up      False
# 9222   Varies with device  Varies with device      False
# 6420                3.2.1          3.0 and up      False
# 6334                4.0.7        4.0.3 and up      False

# %% [markdown]
# ### Part 4 : Isolating the free apps

# %% [markdown]
# As we mentioned in the introduction, we only build apps that are free to download and install, and our main source of revenue consists of in-app ads. Our data sets contain both free and non-free apps, and we'll need to isolate only the free apps for our analysis.

# %%
google = google[google["Price"]=="0"]
apple = apple[apple["price"]==0]
print(google.shape)
print(apple.shape)
# Out:
# (8906, 14)
# (4056, 16)

# %% [markdown]
# ## Gaining Insights from Data
# ## Q1: what are the most common genres for each market?

# %% [markdown]
# To minimize risks and overhead, our validation strategy for an app idea is comprised of three steps:
#
# 1. Build a minimal Android version of the app, and add it to Google Play.
# 2. If the app has a good response from users, we then develop it further.
# 3. If the app is profitable after six months, we also build an iOS version of the app and add it to the App Store.
#
# Because our end goal is to add the app on both the App Store and Google Play, we need to find app profiles that are successful on both markets.
#
# As a first steop, let's find out what genres are most common for each market.

# %% [markdown]
# ### App Store

# %%
apple.prime_genre.value_counts(ascending=False,normalize=True).head(10)*100
# Out:
# Games                55.645957
# Entertainment         8.234714
# Photo & Video         4.117357
# Social Networking     3.525641
# Education             3.254438
# Shopping              2.983235
# Utilities             2.687377
# Lifestyle             2.317554
# Finance               2.071006
# Sports                1.947732
# Name: prime_genre, dtype: float64

# %% [markdown]
# Among the free English apps, more than a half (55.64%) are games. Entertainment apps are more than 8%, followed by photo and video apps, which are close to 5%.

# %% [markdown]
# ### GooglePlay Market

# %% [markdown]
# There are two relevant variables we can use in the GooglePlay dataset: *Genres* and *Category*. Since the *Genres* column is much more granular (it has more categories), we'll focus on on *Category*. Let's make a normalized frequency table for *Category*.

# %%
google.Category.value_counts(ascending=False,normalize=True).head(15)*100
# Out:
# FAMILY                19.011791
# GAME                   9.691185
# TOOLS                  8.433464
# BUSINESS               4.581696
# LIFESTYLE              3.930376
# PRODUCTIVITY           3.885458
# FINANCE                3.683324
# MEDICAL                3.514879
# SPORTS                 3.380124
# PERSONALIZATION        3.312746
# COMMUNICATION          3.234138
# HEALTH_AND_FITNESS     3.065693
# PHOTOGRAPHY            2.942167
# NEWS_AND_MAGAZINES     2.829871
# SOCIAL                 2.650197
# Name: Category, dtype: float64

# %% [markdown]
# The landscape seems significantly different on Google Play: there is not a single category that dominates the market and we do see a higher number of apps designed for practical purposes. However, if we look closer, the family category (which accounts for almost 19% of the apps) means mostly games for kids.
#
# The most common genres may not be the most popular genres. In the next section, we'll explore what kind of apps have most users.

# %% [markdown]
# ## Q2 : what are the most popular genres for each market?
# The metric we'll use to measure popularity is the average number of installs for each app genre. For the Google Play data set, we can find this information in the *Installs* column, but for the App Store data set this information is missing. We'll take the total number of user ratings as a proxy, which we can find in the *rating_count_tot app*.

# %% [markdown]
# ### App Store

# %%
apple_avg_rating_by_genre = apple.groupby(by="prime_genre").mean()["rating_count_tot"].sort_values(ascending=False)
apple_avg_rating_by_genre
# Out:
# prime_genre
# Reference            67447.900000
# Music                56482.029851
# Social Networking    53078.195804
# Weather              47220.935484
# Photo & Video        27249.892216
# Navigation           25972.050000
# Travel               20216.017857
# Food & Drink         20179.093023
# Sports               20128.974684
# Health & Fitness     19952.315789
# Productivity         19053.887097
# Games                18924.688968
# Shopping             18746.677686
# News                 15892.724138
# Utilities            14010.100917
# Finance              13522.261905
# Entertainment        10822.961078
# Lifestyle             8978.308511
# Book                  8498.333333
# Business              6367.800000
# Education             6266.333333
# Catalogs              1779.555556
# Medical                459.750000
# Name: rating_count_tot, dtype: float64

# %% [markdown]
# We see that the most popular genres are significantly differnet from the most common genres. The genres that have the highest average number of user ratings is Reference, followed by Music, Soicla Networking and Weather. Our popularity metric for the most common category, Games, is only 1/4 of that for Reference category.
#
# However, the average number of user ratings only gives us a very high-level overview of the popularity of genres. Let's look closer.

# %%
reference = apple.loc[apple["prime_genre"] == "Reference", ["track_name","rating_count_tot"]]
reference.head(10)
# Out:
#                                              track_name  rating_count_tot
# 6                                                 Bible            985920
# 90                Dictionary.com Dictionary & Thesaurus            200047
# 335      Dictionary.com Dictionary & Thesaurus for iPad             54175
# 551                                    Google Translate             26786
# 715   Muslim Pro: Ramadan 2017 Prayer Times, Azan, Q...             18418
# 738   New Furniture Mods - Pocket Wiki & Game Tools ...             17588
# 757                          Merriam-Webster Dictionary             16849
# 913                                           Night Sky             12122
# 1106  City Maps for Minecraft PE - The Best Maps for...              8535
# 1451  LUCKY BLOCK MOD ™ for Minecraft PC Edition - T...              4693

# %%
social = apple.loc[apple["prime_genre"] == "Social Networking", ["track_name","rating_count_tot"]]
social.head(10)
# Out:
#                                   track_name  rating_count_tot
# 0                                   Facebook           2974676
# 5                                  Pinterest           1061624
# 43                          Skype for iPhone            373519
# 48                                 Messenger            351466
# 51                                    Tumblr            334293
# 63                        WhatsApp Messenger            287589
# 72                                       Kik            260965
# 111  ooVoo – Free Video Call, Text and Voice            177501
# 117         TextNow - Unlimited Text + Calls            164963
# 120            Viber Messenger – Text & Call            164249

# %% [markdown]
# For Social Networking apps, the average number of ratings is heavily influenced by a few giants like Facebook, Pinterest, Skype, etc. Same applies to Reference apps, which have 74,942 user ratings on average, but it's actually the Bible and Dictionary.com that skew up the average rating counts. We see the same pattern in Navigation and Music apps.
#
# One way to address the skewness of rating counts is to remove the extremly popular apps for each genre and then rework the averages. A better way may be to keep the outliers in the data but make sure to highlight these high influence apps when presenting our findings to business development team.

# %% [markdown]
# ### GooglePlay Market

# %% [markdown]
# For the Google Play market, we actually have data about the number of installs, so we should be able to get a clearer picture about genre popularity. However, the install numbers don't seem precise enough — we can see that most values are not precise (100+, 1,000+, 5,000+, etc.):

# %%
google["Installs"].value_counts().head(10)
# Out:
# 1,000,000+     1397
# 100,000+       1031
# 10,000,000+     935
# 10,000+         913
# 1,000+          751
# 100+            616
# 5,000,000+      607
# 500,000+        493
# 50,000+         429
# 5,000+          403
# Name: Installs, dtype: int64

# %% [markdown]
# Though the precision of these numbers is not ideal, we'll work with what is available to get a high-level sense of the popularity of each genre. We'll need to convert each install number to float — this means that we need to remove the commas and the plus characters.

# %%
google["Installs"] = google["Installs"].str.replace(",","").str.replace("+","")
google["Installs"] = google["Installs"].apply(float)

# %%
google_avg_install_by_genre = google.groupby(by="Category").mean()["Installs"].sort_values(ascending=False)
google_avg_install_by_genre
# Out:
# Category
# COMMUNICATION          3.832263e+07
# VIDEO_PLAYERS          2.457395e+07
# SOCIAL                 2.325365e+07
# PHOTOGRAPHY            1.777202e+07
# PRODUCTIVITY           1.673896e+07
# GAME                   1.555843e+07
# TRAVEL_AND_LOCAL       1.398408e+07
# ENTERTAINMENT          1.171976e+07
# TOOLS                  1.078701e+07
# NEWS_AND_MAGAZINES     9.401636e+06
# BOOKS_AND_REFERENCE    8.587352e+06
# SHOPPING               7.001693e+06
# PERSONALIZATION        5.183851e+06
# WEATHER                5.074486e+06
# HEALTH_AND_FITNESS     4.188822e+06
# MAPS_AND_NAVIGATION    3.993340e+06
# FAMILY                 3.671820e+06
# SPORTS                 3.638640e+06
# ART_AND_DESIGN         1.952105e+06
# FOOD_AND_DRINK         1.924898e+06
# EDUCATION              1.833495e+06
# BUSINESS               1.708216e+06
# LIFESTYLE              1.436127e+06
# FINANCE                1.387692e+06
# HOUSE_AND_HOME         1.331541e+06
# DATING                 8.540288e+05
# COMICS                 8.032348e+05
# AUTO_AND_VEHICLES      6.473178e+05
# LIBRARIES_AND_DEMO     6.385037e+05
# PARENTING              5.426036e+05
# BEAUTY                 5.131519e+05
# EVENTS                 2.535422e+05
# MEDICAL                1.205506e+05
# Name: Installs, dtype: float64

# %% [markdown]
# On average, communication apps have the most installs. This number is heavily skewed up by a few apps that have over one billion installs (WhatsApp, Facebook Messenger, Skype, Google Chrome, Gmail, and Hangouts), and a few others with over 100 and 500 million installs:

# %%
google.loc[google["Category"] == "COMMUNICATION",["App","Installs"]].sort_values(by="Installs",ascending=False)
# Out:
#                                                      App      Installs
# 451                                                Gmail  1.000000e+09
# 4234                       Skype - free IM & video calls  1.000000e+09
# 464                                             Hangouts  1.000000e+09
# 381                                   WhatsApp Messenger  1.000000e+09
# 382             Messenger – Text and Video Chat for Free  1.000000e+09
# 411                         Google Chrome: Fast & Secure  1.000000e+09
# 474                          LINE: Free Calls & Messages  5.000000e+08
# 4676                                     Viber Messenger  5.000000e+08
# 420          UC Browser - Fast Download Private & Secure  5.000000e+08
# 4039               Google Duo - High Quality Video Calls  5.000000e+08
# 465                        imo free video calls and chat  5.000000e+08
# 4712                                              WeChat  1.000000e+08
# 4592                                            Telegram  1.000000e+08
# 4602   Truecaller: Caller ID, SMS spam blocking & Dialer  1.000000e+08
# 396                                     Android Messages  1.000000e+08
# 393                                                  Who  1.000000e+08
# 4421                       Opera Mini - fast web browser  1.000000e+08
# 4422                      Opera Browser: Fast and Secure  1.000000e+08
# 412                       Firefox Browser fast & private  1.000000e+08
# 6449                         BBM - Free Calls & Messages  1.000000e+08
# 395           GO SMS Pro - Messenger, Free Themes, Emoji  1.000000e+08
# 4800                         Yahoo Mail – Stay Organized  1.000000e+08
# 4633         UC Browser Mini -Tiny Fast Private & Secure  1.000000e+08
# 4106               Messenger Lite: Free Calls & Messages  1.000000e+08
# 4123                        imo beta free calls and text  1.000000e+08
# 4302                        KakaoTalk: Free Calls & Text  1.000000e+08
# 4279                                                 Kik  1.000000e+08
# 418           Dolphin Browser - Fast, Private & Adblock🐬  5.000000e+07
# 459                                  Mail.Ru - Email App  5.000000e+07
# 348                                             Contacts  5.000000e+07
# ...                                                  ...           ...
# 10694                                          FO SODEXO  1.000000e+02
# 8384                                             DG Card  1.000000e+02
# 8096                                        Cy Messenger  1.000000e+02
# 10704                                  FO STELIA Méaulte  1.000000e+02
# 10734                                         FP Connect  1.000000e+02
# 10439                            Carpooling FH Hagenberg  1.000000e+02
# 8005                                    CW Bluetooth SPP  1.000000e+02
# 9913                                 Programi podrške EU  1.000000e+02
# 8068                               Hyundai CX Conference  5.000000e+01
# 6443                                               AC-BL  5.000000e+01
# 6727                                           BS-Mobile  5.000000e+01
# 7142                                          Cb browser  5.000000e+01
# 8504                                       DK TEL Dialer  5.000000e+01
# 7485                                         CK Call NEW  1.000000e+01
# 8147                                  Hlášenírozhlasu.cz  1.000000e+01
# 10748                                            FP Live  1.000000e+01
# 6046                   Best Browser BD social networking  1.000000e+01
# 8497                                          DK Browser  1.000000e+01
# 5100                           Oklahoma Ag Co-op Council  1.000000e+01
# 10670                                       FN Web Radio  1.000000e+01
# 9412                                                  ei  1.000000e+01
# 8556                      DM - The Offical Messaging App  1.000000e+01
# 9455                                        EJ messenger  1.000000e+01
# 6328                                   BJ - Confidential  1.000000e+01
# 9648                                           EO Mumbai  1.000000e+01
# 10672                                   FNH Payment Info  1.000000e+01
# 9514                                              Ek IRA  1.000000e+01
# 10169                                 Test Server SMS FA  5.000000e+00
# 6399                              Of the wall Arapaho bk  5.000000e+00
# 5921                                            BA SALES  1.000000e+00
#
# [288 rows x 2 columns]

# %% [markdown]
# We see the same pattern for the video players category, which is dominated by apps like Youtube, Google Play Movies & TV, or MX Player. The pattern is repeated for social apps (where we have giants like Facebook, Instagram, Google+, etc.), photography apps (Google Photos and other popular photo editors), or productivity apps (Microsoft Word, Dropbox, Google Calendar, Evernote, etc.).
#
# Similar to our concern over our analysis of GooglePlay Apps, the main concern is that these app genres
#
# - appear more popular they they really are;
# - are already highly saturated with a few giants dominating the market.
#
# So we'd like to come up with a different app recommendation if possible.
#
# The books and reference genre looks fairly popular as well. We found this genre has some potential to work well on both GoolePlay and App Store.
#
# Let's take a look at some of the apps from this genre and their number of installs:

# %%
google.loc[google["Category"] == "BOOKS_AND_REFERENCE",["App","Installs"]].sort_values(by="Installs",ascending=False)
# Out:
#                                                      App      Installs
# 152                                    Google Play Books  1.000000e+09
# 3941                                               Bible  1.000000e+08
# 4715                                Wattpad 📖 Free Books  1.000000e+08
# 5651                             Audiobooks from Audible  1.000000e+08
# 4083                                       Amazon Kindle  1.000000e+08
# 5319                                     Al-Quran (Free)  1.000000e+07
# 5345                                   Quran for Android  1.000000e+07
# 9625                                          JW Library  1.000000e+07
# 179                                         Moon+ Reader  1.000000e+07
# 144                                          Cool Reader  1.000000e+07
# 6497                       NOOK: Read eBooks & Magazines  1.000000e+07
# 149                       FBReader: Favorite Book Reader  1.000000e+07
# 4100                                  Aldiko Book Reader  1.000000e+07
# 9642                 Oxford Dictionary of English : Free  1.000000e+07
# 5324                           Al'Quran Bahasa Indonesia  1.000000e+07
# 5323                                  Al Quran Indonesia  1.000000e+07
# 173                                             HTC Help  1.000000e+07
# 8293                                          Dictionary  1.000000e+07
# 9643                            English Hindi Dictionary  1.000000e+07
# 9621                        Dictionary - Merriam-Webster  1.000000e+07
# 6296                        English Dictionary - Offline  1.000000e+07
# 142                                            Wikipedia  1.000000e+07
# 6290   Dictionary.com: Find Definitions for English W...  1.000000e+07
# 9570                          Spanish English Translator  1.000000e+07
# 9644                         English to Hindi Dictionary  5.000000e+06
# 5334       Al Quran : EAlim - Translations & MP3 Offline  5.000000e+06
# 6298                                           Bible KJV  5.000000e+06
# 4740                                Dictionary - WordWeb  5.000000e+06
# 5076                 50000 Free eBooks & Free AudioBooks  5.000000e+06
# 172                                             Ancestry  5.000000e+06
# ...                                                  ...           ...
# 10342                                     La Fe de Jesus  1.000000e+03
# 10833                                        Chemin (fr)  1.000000e+03
# 8960                               DV 2018 Winners Guide  1.000000e+03
# 8267                                   DC Public Library  1.000000e+03
# 8431                           D. H. Lawrence Poems FREE  1.000000e+03
# 6165                                         Cъновник BG  1.000000e+03
# 9777                           FAHREDDİN er-RÂZİ TEFSİRİ  1.000000e+03
# 6840                               Catholic La Bu Zo Kam  5.000000e+02
# 8160                                Modlitební knížka CZ  5.000000e+02
# 7725                            SDA Collegiate Quarterly  5.000000e+02
# 6915                                Learn SAP BW on HANA  5.000000e+02
# 6904                                        Learn SAP BW  5.000000e+02
# 10359                                     Le Fe de Jesus  5.000000e+02
# 10346                                     La Fe de Jesús  5.000000e+02
# 6464                                    MOD Black for BM  1.000000e+02
# 6492                                    Anime Mod for BM  1.000000e+02
# 7747                             Cypress College Library  1.000000e+02
# 6838                                           BU Alsace  1.000000e+02
# 9916                                         EU IP Codes  1.000000e+02
# 9255                        CompactiMa EC pH Calibration  1.000000e+02
# 7843           GATE 21 years CS Papers(2011-2018 Solved)  5.000000e+01
# 5259                                     A-J Media Vault  5.000000e+01
# 8232                                    Guide for IMS DB  1.000000e+01
# 6844                               Khrifa Hla Bu (Solfa)  1.000000e+01
# 8114                                     CY Spray nozzle  1.000000e+01
# 4546                                 Learn R Programming  1.000000e+01
# 4543                             Guide for R Programming  5.000000e+00
# 8146                                             CZ-Help  5.000000e+00
# 9993                                              EW PDF  5.000000e+00
# 8119                              BibleRead En Cy Zh Yue  5.000000e+00
#
# [194 rows x 2 columns]

# %% [markdown]
# ## Conclusion
# In this project, we analyzed data about the App Store and Google Play mobile apps with the goal of recommending an app profile that can be profitable for both markets.
#
# We concluded that
#
# - the most popular genres, such as Social Networking (Communication) are already highly saturated and dominiated by a few giants, thus presenting great barriers of entry;
# - taking a popular collection of books and turning it into an app could be profitable for both the Google Play and the App Store markets. In order to distinguish our products from the already existing libraries, we need to add some special features, such as audio version of the books in our collection, anotation and sharing tools, etc.
